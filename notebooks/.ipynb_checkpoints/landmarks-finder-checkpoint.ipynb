# %%
import anndata as ad
import scanpy as sc
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import squidpy as sq

# %%
CNTPTH_1 = "/home/alma/w-projects/ccf/data/science-mob/Rep11_MOB.h5ad"
CNTPTH_2 = "/home/alma/w-projects/ccf/data/science-mob/Rep12_MOB.h5ad"

# %%
adata_1 = sc.read_h5ad(CNTPTH_1)

# %%
sc.pl.spatial(adata_1,color ="Penk")

# %%
sc.pp.normalize_per_cell(adata_1,1e4)
sc.pp.log1p(adata_1)
sc.pp.highly_variable_genes(adata_1)
sc.tl.pca(adata_1)
sc.pp.neighbors(adata_1,n_neighbors=15)
sc.tl.umap(adata_1)

# %%
sq.gr.spatial_neighbors(adata_1,n_neigh=4)

# %%
sc.pl.embedding(adata_1,basis ="umap")

# %%
adata_1
# Out:
# AnnData object with n_obs × n_vars = 262 × 16218
#     obs: 'spot', 'n_counts'
#     var: 'gene', 'highly_variable', 'means', 'dispersions', 'dispersions_norm'
#     uns: 'spatial', 'log1p', 'hvg', 'pca', 'neighbors', 'umap', 'spatial_neighbors'
#     obsm: 'spatial', 'X_pca', 'X_umap'
#     varm: 'PCs'
#     obsp: 'distances', 'connectivities', 'spatial_connectivities'

# %%
em_gr = adata_1.obsp["distances"]

# %%
for ii in range(adata_1.shape[0]):
    print(em_gr.indices[em_gr.indptr[ii]:em_gr.indptr[ii+1]].shape)
# Out:
# (14,)
# (14,)
# (14,)
# (14,)
# (14,)
# (14,)
# (14,)
# (14,)
# (14,)
# (14,)
# (14,)
# (14,)
# (14,)
# (14,)
# (14,)
# (14,)
# (14,)
# (14,)
# (14,)
# (14,)
# (14,)
# (14,)
# (14,)
# (14,)
# (14,)
# (14,)
# (14,)
# (14,)
# (14,)
# (14,)
# (14,)
# (14,)
# (14,)
# (14,)
# (14,)
# (14,)
# (14,)
# (14,)
# (14,)
# (14,)
# (14,)
# (14,)
# (14,)
# (14,)
# (14,)
# (14,)
# (14,)
# (14,)
# (14,)
# (14,)
# (14,)
# (14,)
# (14,)
# (14,)
# (14,)
# (14,)
# (14,)
# (14,)
# (14,)
# (14,)
# (14,)
# (14,)
# (14,)
# (14,)
# (14,)
# (14,)
# (14,)
# (14,)
# (14,)
# (14,)
# (14,)
# (14,)
# (14,)
# (14,)
# (14,)
# (14,)
# (14,)
# (14,)
# (14,)
# (14,)
# (14,)
# (14,)
# (14,)
# (14,)
# (14,)
# (14,)
# (14,)
# (14,)
# (14,)
# (14,)
# (14,)
# (14,)
# (14,)
# (14,)
# (14,)
# (14,)
# (14,)
# (14,)
# (14,)
# (14,)
# (14,)
# (14,)
# (14,)
# (14,)
# (14,)
# (14,)
# (14,)
# (14,)
# (14,)
# (14,)
# (14,)
# (14,)
# (14,)
# (14,)
# (14,)
# (14,)
# (14,)
# (14,)
# (14,)
# (14,)
# (14,)
# (14,)
# (14,)
# (14,)
# (14,)
# ...

# %%
nbr_mat = np.zeros((adata_1.shape[0],14))
for ii in range(adata_1.shape[0]):
    #nbr_mat[ii,:] = em_gr.indices[em_gr.indptr[ii]:em_gr.indptr[ii+1]]
    nbr_mat[ii,:] = em_gr.indices[em_gr.indptr[ii]:em_gr.indptr[ii+1]]

adata_1.obsm["em_nbr_mat"] = nbr_mat
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-72-b03a2ac43b29> in <module>
#       1 nbr_mat = np.zeros((adata_1.shape[0],14))
#       2 for ii in range(adata_1.shape[0]):
# ----> 3     nbr_mat[ii,:] = em_gr.indices[em_gr.indptr[ii]:em_gr.indptr[ii+1]]
#       4 adata_1.obsm["em_nmbr_mat"] = nbr_mat
#
# ValueError: could not broadcast input array from shape (22) into shape (14)

# %%
nbr_mat[ii,]
# Out:
# array([[  91.,   91.,   91., ...,   91.,   91.,   91.],
#        [ 156.,  156.,  156., ...,  156.,  156.,  156.],
#        [ 260.,  260.,  260., ...,  260.,  260.,  260.],
#        ...,
#        [5850., 5850., 5850., ..., 5850., 5850., 5850.],
#        [   0.,    0.,    0., ...,    0.,    0.,    0.],
#        [  91.,   91.,   91., ...,   91.,   91.,   91.]])

# %%
ux = adata_1.obsm["X_umap"][:,0]
uy = adata_1.obsm["X_umap"][:,1]
plt.scatter(ux,uy,color ="gray")
plt.scatter(ux[ii],uy[ii])
plt.scatter(ux[nbr_mat[ii,:]],uy[nbr_mat[ii,:]])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-63-7f427b7727da> in <module>
#       3 plt.scatter(ux,uy,color ="gray")
#       4 plt.scatter(ux[ii],uy[ii])
# ----> 5 plt.scatter(ux[nbr_mat[ii,:]],uy[nbr_mat[ii,:]])
#
# IndexError: arrays used as indices must be of integer (or boolean) type

# %%
plt.imshow(adata_1.obsp["spatial_connectivities"].todense())

# %%
sp_gr = adata_1.obsp["spatial_connectivities"].todense()

# %%
em_gr.indices,em_gr.indptr
# Out:
# (array([  5,   7,  12, ..., 239, 242, 256], dtype=int32),
#  array([   0,   14,   36,   50,   70,   91,  120,  156,  173,  187,  232,
#          246,  260,  330,  366,  392,  419,  447,  465,  489,  509,  523,
#          537,  551,  565,  593,  616,  648,  663,  682,  718,  747,  774,
#          788,  825,  872,  895,  959,  981, 1014, 1076, 1103, 1132, 1147,
#         1178, 1193, 1207, 1224, 1239, 1266, 1288, 1315, 1340, 1367, 1381,
#         1404, 1422, 1448, 1462, 1481, 1497, 1518, 1538, 1552, 1579, 1596,
#         1614, 1629, 1655, 1669, 1697, 1724, 1738, 1756, 1788, 1805, 1831,
#         1851, 1876, 1891, 1908, 1922, 1939, 1972, 2001, 2024, 2061, 2086,
#         2104, 2120, 2134, 2163, 2191, 2224, 2240, 2270, 2285, 2316, 2338,
#         2361, 2390, 2422, 2436, 2451, 2496, 2534, 2554, 2573, 2594, 2616,
#         2642, 2675, 2739, 2774, 2790, 2812, 2828, 2842, 2873, 2908, 2929,
#         2953, 2967, 2981, 2999, 3015, 3037, 3051, 3070, 3084, 3129, 3175,
# ...
